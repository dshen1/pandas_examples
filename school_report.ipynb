# %%
# !wget http://dise.in/Downloads/Publications/Publications%202010-11/DRC2010-11/DRC_Raw_Data2010-11.xls
# Out:
# --2017-01-28 07:36:51--  http://dise.in/Downloads/Publications/Publications%202010-11/DRC2010-11/DRC_Raw_Data2010-11.xls
# Resolving dise.in (dise.in)... 14.139.60.149
# Connecting to dise.in (dise.in)|14.139.60.149|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2490472 (2.4M) [application/vnd.ms-excel]
# Saving to: `DRC_Raw_Data2010-11.xls'
#
# 100%[======================================>] 2,490,472    877K/s   in 2.8s
#
# 2017-01-28 07:36:55 (877 KB/s) - `DRC_Raw_Data2010-11.xls' saved [2490472/2490472]

# %%
import pandas as pd

# %%
xl=pd.ExcelFile('DRC_Raw_Data2010-11.xls')

# %%
basic=xl.parse('Basic Data', skiprows=15)

# %%
basic.groupby('statename').agg({'totschools':sum}).sort_values(['totschools']).stack().unstack('statename')
# Out:
# statename   Lakshadweep  DAMAN & DIU  CHANDIGARH  DADRA & NAGAR HAVELI  \
# totschools           46          110         184                   297
#
# statename   ANDAMAN & NICOBAR ISLANDS  PUDUCHERRY  SIKKIM   GOA  NAGALAND  \
# totschools                        406         709    1201  1491      2826
#
# statename   MIZORAM      ...        KARNATAKA  ASSAM  ORISSA  BIHAR  \
# totschools     2904      ...            59484  64653   65730  69379
#
# statename   WEST BENGAL  MAHARASHTRA  RAJASTHAN  ANDHRA PRADESH  \
# totschools        90187        97278     105190          107597
#
# statename   MADHYA PRADESH  UTTAR PRADESH
# totschools          137113         201475
#
# [1 rows x 35 columns]

# %%
# %matplotlib inline

# %%
basic.groupby('statename').agg({'totschools':sum}).sort_values(['totschools']).sort('totschools', ascending=False).stack().unstack('statename').plot(kind='barh')
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
